# %%
import json

# %%
with open('data/ww1-wiki-ar.json', encoding="utf-8") as f:
    data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 with open('data/ww1-wiki-ar.json', encoding="utf-8") as f:
#       2     data = json.load(f)
#
# File c:\Users\Lenovo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ww1-wiki-ar.json'

# %%
page = next(iter(data['query']['pages'].values()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 page = next(iter(data['query']['pages'].values()))
#
# NameError: name 'data' is not defined

# %%
with open('ww1-wiki-ar.txt', 'w', encoding='utf-8') as f:
    f.write(page['extract'])

# %%
with open('test.txt', 'w') as f:
    f.write('hello\nthere')

# %%
print(f'\\ sdasdsad')
# Out:
# \ sdasdsad

# %%
import unicodedata

# %%
for ch in "لْگ":
    print(repr(ch), unicodedata.category(ch), unicodedata.name(ch, "UNKNOWN"))
# Out:
# 'ل' Lo ARABIC LETTER LAM
# 'ْ' Mn ARABIC SUKUN
# 'گ' Lo ARABIC LETTER GAF

# %%
GPT4_SPLIT_PATTERN = r"""'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+"""
GPT2_SPLIT_PATTERN = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
GPT2_SPLIT_PATTERN_DIACRITICS = r"""'(?:[sdmt]|ll|ve|re)| ?(?:\p{L}\p{Mn}*)+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

import regex as re
pattern = re.compile(GPT2_SPLIT_PATTERN_DIACRITICS)

# %%
test_text = '''توقَّف التقدم الألماني في فرنسا في معركة المارن، وبحلول نهاية عام 1914 استقرت الجبهة الغربية على حرب استنزاف تميزت بسلسلة طويلة من خطوط الخنادق التي قليلاً ما تغيَّرت حتى عام 1917. على الجبهة الشرقية دخل جيشان روسيان شرق بروسيا في 17 أغسطس بناءً للاتفاق مع فرنسا عام 1912 بمهاجمة ألمانيا خلال 15 يومًا من التعبئة. أجبر الألمان على تحويل قوات من الغرب، لكنهم نجحوا في صدِّ هذا الغزو بانتصارٍ في معركة تاننبرغ ومعركة بحيرات ماسوريان الأولى، ومع ذلك احتل الروس مقاطعة غاليسيا الشرقية في النمسا-المجر.'''
test_text_en = '''For dicts to be ordered, you need Python 3.7+, or 3.6+ if you're okay with relying on the technically-an-implementation-detail ordered nature of dicts on CPython 3.6.'''

# %%
test_text
# Out:
# 'توقَّف التقدم الألماني في فرنسا في معركة المارن، وبحلول نهاية عام 1914 استقرت الجبهة الغربية على حرب استنزاف تميزت بسلسلة طويلة من خطوط الخنادق التي قليلاً ما تغيَّرت حتى عام 1917. على الجبهة الشرقية دخل جيشان روسيان شرق بروسيا في 17 أغسطس بناءً للاتفاق مع فرنسا عام 1912 بمهاجمة ألمانيا خلال 15 يومًا من التعبئة. أجبر الألمان على تحويل قوات من الغرب، لكنهم نجحوا في صدِّ هذا الغزو بانتصارٍ في معركة تاننبرغ ومعركة بحيرات ماسوريان الأولى، ومع ذلك احتل الروس مقاطعة غاليسيا الشرقية في النمسا-المجر.'

# %%
re.findall(pattern, test_text)
# Out:
# ['توقَّف',
#  ' التقدم',
#  ' الألماني',
#  ' في',
#  ' فرنسا',
#  ' في',
#  ' معركة',
#  ' المارن',
#  '،',
#  ' وبحلول',
#  ' نهاية',
#  ' عام',
#  ' 1914',
#  ' استقرت',
#  ' الجبهة',
#  ' الغربية',
#  ' على',
#  ' حرب',
#  ' استنزاف',
#  ' تميزت',
#  ' بسلسلة',
#  ' طويلة',
#  ' من',
#  ' خطوط',
#  ' الخنادق',
#  ' التي',
#  ' قليلاً',
#  ' ما',
#  ' تغيَّرت',
#  ' حتى',
#  ' عام',
#  ' 1917',
#  '.',
#  ' على',
#  ' الجبهة',
#  ' الشرقية',
#  ' دخل',
#  ' جيشان',
#  ' روسيان',
#  ' شرق',
#  ' بروسيا',
#  ' في',
#  ' 17',
#  ' أغسطس',
#  ' بناءً',
#  ' للاتفاق',
#  ' مع',
#  ' فرنسا',
#  ' عام',
#  ' 1912',
#  ' بمهاجمة',
#  ' ألمانيا',
#  ' خلال',
#  ' 15',
#  ' يومًا',
#  ' من',
#  ' التعبئة',
#  '.',
#  ' أجبر',
#  ' الألمان',
#  ' على',
#  ' تحويل',
#  ' قوات',
#  ' من',
#  ' الغرب',
#  '،',
#  ' لكنهم',
#  ' نجحوا',
#  ' في',
#  ' صدِّ',
#  ' هذا',
#  ' الغزو',
#  ' بانتصارٍ',
#  ' في',
#  ' معركة',
#  ' تاننبرغ',
#  ' ومعركة',
#  ' بحيرات',
#  ' ماسوريان',
#  ' الأولى',
# ...

# %%
re.findall(pattern, test_text)
# Out:
# ['توقَّف',
#  ' التقدم',
#  ' الألماني',
#  ' في',
#  ' فرنسا',
#  ' في',
#  ' معركة',
#  ' المارن',
#  '،',
#  ' وبحلول',
#  ' نهاية',
#  ' عام',
#  ' 1914',
#  ' استقرت',
#  ' الجبهة',
#  ' الغربية',
#  ' على',
#  ' حرب',
#  ' استنزاف',
#  ' تميزت',
#  ' بسلسلة',
#  ' طويلة',
#  ' من',
#  ' خطوط',
#  ' الخنادق',
#  ' التي',
#  ' قليلاً',
#  ' ما',
#  ' تغيَّرت',
#  ' حتى',
#  ' عام',
#  ' 1917',
#  '.',
#  ' على',
#  ' الجبهة',
#  ' الشرقية',
#  ' دخل',
#  ' جيشان',
#  ' روسيان',
#  ' شرق',
#  ' بروسيا',
#  ' في',
#  ' 17',
#  ' أغسطس',
#  ' بناءً',
#  ' للاتفاق',
#  ' مع',
#  ' فرنسا',
#  ' عام',
#  ' 1912',
#  ' بمهاجمة',
#  ' ألمانيا',
#  ' خلال',
#  ' 15',
#  ' يومًا',
#  ' من',
#  ' التعبئة',
#  '.',
#  ' أجبر',
#  ' الألمان',
#  ' على',
#  ' تحويل',
#  ' قوات',
#  ' من',
#  ' الغرب',
#  '،',
#  ' لكنهم',
#  ' نجحوا',
#  ' في',
#  ' صدِّ',
#  ' هذا',
#  ' الغزو',
#  ' بانتصارٍ',
#  ' في',
#  ' معركة',
#  ' تاننبرغ',
#  ' ومعركة',
#  ' بحيرات',
#  ' ماسوريان',
#  ' الأولى',
# ...

# %%
a = {"1":1, "2":2}

# %%
assert all(isinstance(k, str) and isinstance(v, int) for k, v in a.items())

# %%
placeholder = dict()
placeholder = a

# %%
placeholder_inv = {v: k for k, v in placeholder.items()}
placeholder_inv, placeholder
# Out:
# ({1: '1', 2: '2'}, {'1': 1, '2': 2})

# %%
x = re.findall(pattern, 'hello. there')
x = [list(chunk.encode('utf-8')) for chunk in x]
x
# Out:
# [[104, 101, 108, 108, 111], [46], [32, 116, 104, 101, 114, 101]]
